# %% [markdown]
# # 中文分词、词频统计、词云图

# %%
import jieba
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
# 根据实际情况纠正jieba分词的不准确
jieba.load_userdict('dict_digitaleconomy.txt')

# %%
stopword_file = 'E:/Tools/stopwords/hit_stopwords.txt'
process_file = 'E:/Tools/Chinese_Text_Split_Wordcloud/policy_digital_economy.txt'

# %%
#停用词表
with open(stopword_file, 'r', encoding='utf-8') as f:
    stopword_list = [word.strip('\n') for word in f.readlines()]
    print(stopword_list)
# Out:
# ['———', '》），', '）÷（１－', '”，', '）、', '＝（', ':', '→', '℃ ', '&', '*', '一一', '~~~~', '’', '. ', '『', '.一', './', '-- ', '』', '＝″', '【', '［＊］', '｝＞', '［⑤］］', '［①Ｄ］', 'ｃ］', 'ｎｇ昉', '＊', '//', '［', '］', '［②ｅ］', '［②ｇ］', '＝｛', '}', '，也 ', '‘', 'Ａ', '［①⑥］', '［②Ｂ］ ', '［①ａ］', '［④ａ］', '［①③］', '［③ｈ］', '③］', '１． ', '－－ ', '［②ｂ］', '’‘ ', '××× ', '［①⑧］', '０：２ ', '＝［', '［⑤ｂ］', '［②ｃ］ ', '［④ｂ］', '［②③］', '［③ａ］', '［④ｃ］', '［①⑤］', '［①⑦］', '［①ｇ］', '∈［ ', '［①⑨］', '［①④］', '［①ｃ］', '［②ｆ］', '［②⑧］', '［②①］', '［①Ｃ］', '［③ｃ］', '［③ｇ］', '［②⑤］', '［②②］', '一.', '［①ｈ］', '.数', '［］', '［①Ｂ］', '数/', '［①ｉ］', '［③ｅ］', '［①①］', '［④ｄ］', '［④ｅ］', '［③ｂ］', '［⑤ａ］', '［①Ａ］', '［②⑧］', '［②⑦］', '［①ｄ］', '［②ｊ］', '〕〔', '］［', '://', '′∈', '［②④', '［⑤ｅ］', '１２％', 'ｂ］', '...', '...................', '…………………………………………………③', 'ＺＸＦＩＴＬ', '［③Ｆ］', '」', '［①ｏ］', '］∧′＝［ ', '∪φ∈', '′｜', '｛－', '②ｃ', '｝', '［③①］', 'Ｒ．Ｌ．', '［①Ｅ］', 'Ψ', '－［＊］－', '↑', '.日 ', '［②ｄ］', '［②', '［②⑦］', '［②②］', '［③ｅ］', '［①ｉ］', '［①Ｂ］', '［①ｈ］', '［①ｄ］', '［①ｇ］', '［①②］', '［②ａ］', 'ｆ］', '［⑩］', 'ａ］',
# ...

# %%
# 分词，并去掉停用词
result = ""
with open(process_file,encoding = "utf-8") as f:
    mytext = f.read()
word_list = jieba.lcut(mytext)
for w in word_list:
    if w not in stopword_list:
        result = result + " " + w

# %%
print(result)
# Out:
#  国务院 印发
#
#  十四五 数字经济 发展 规划 通知
#
#  国 发 2021 29 号
#
#
#  各省 自治区 直辖市 人民政府 国务院 各部委 直属机构
#
#  现将 十四五 数字经济 发展 规划 印发 请 认真贯彻 执行
#
#  国务院
#
#  2021 年 12 月 12 日
#
#  此件 公开 发布
#
#
#
#  十四五 数字经济 发展 规划
#
#
#  数字经济 继 农业经济 工业经济 之后 主要 经济 形态 数据资源 关键 要素 现代 信息网络 主要 载体 信息 通信 技术 融合 应用 全要素 数字化转型 重要 推动力 促进 公平 效率 更加 统一 新 经济 形态 数字经济 发展 速度 之快 辐射 范围 之广 影响 程度 之深 前所未有 正 推动 生产方式 生活 方式 治理 方式 深刻 变革 成为 重组 全球 要素 资源 重塑 全球 经济 结构 改变 全球 竞争 格局 关键 力量 十四五 时期 我国 数字经济 转向 深化 应用 规范 发展 普惠 共享 新 阶段 应对 新 形势 新 挑战 把握 数字化 发展 新机遇 拓展 经济 发展 新 空间 推动 我国 数字经济 健康 发展 依据 中华人民共和国 国民经济 社会 发展 第十四 五年 规划 2035 年 远景 目标 纲要 制定 规划
#
#  发展 现状 形势
#
#  发展 现状
#
#  十三 五 时期 我国 深入 实施 数字经济 发展 战略 不断完善 数字基础设施 加快 培育 新 业态 新 模式 推进 数字产业化 产业数字化 取得 积极 成效 2020 年 我国 数字经济 核心 产业 增加值 占 国内 生产总值 GDP 比重 达到 7.8% 数字经济 经济社会 持续 健康 发展 提供 强大 动力
#
#  信息基础设施 全球 领先 建成 全球 规模 最大 光纤 第四代 移动 通信 4G 网络 第五代 移动 通信 5G 网络 建设 应用 加速 推进 宽带用户 普及率 明显提高 光纤 用户 占 超过 94% 移动 宽带用户 普及率 达到 108% 互联网协议 第六版 IPv6 活跃 用户数 达到 4.6 亿
#
# ...

# %%
# 统计词频
df = pd.DataFrame(result.split( ),columns =["words"])
res_count = df.groupby(["words"]).size().sort_values(ascending=False)
res_count.to_excel("result_count.xlsx")

# %%
# 词云图
wordcloud = WordCloud(font_path = "simsun.ttf").generate(result)
plt.imshow(wordcloud, interpolation = "bilinear")
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)
